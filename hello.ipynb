# %% [markdown]
# # Introduction to Jupyter Notebook
#
# To run this notebook,  you need to install leafmap:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhattarainemi/geog510-demo-nb/blob/main/hello.ipynb)

# %%
print ("Hello, World!")

# %%
import os

# %%
os.getcwd()

# %%
x = 1
y =-3
z = x+y

# %%
z

# %%
import leafmap
m  = leafmap.Map()
m
